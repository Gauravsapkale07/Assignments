# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import GridSearchCV, train_test_split
from imblearn.over_sampling import SMOTE
from sklearn.ensemble import BaggingClassifier, GradientBoostingClassifier, RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from xgboost import XGBClassifier
from sklearn.metrics import classification_report
import warnings
warnings.filterwarnings('ignore')
plt.rcParams['figure.figsize'] = (14,8)
# %matplotlib inline

# %%
data = pd.read_excel(r"D:\ExcelR Assignments\Question\Random Forest\Random Forest\glass.xlsx", sheet_name = 'glass')

# %%
data
# Out:
#           RI     Na    Mg    Al     Si     K    Ca    Ba   Fe  Type
# 0    1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.00  0.0     1
# 1    1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.00  0.0     1
# 2    1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.00  0.0     1
# 3    1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.00  0.0     1
# 4    1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.00  0.0     1
# ..       ...    ...   ...   ...    ...   ...   ...   ...  ...   ...
# 209  1.51623  14.14  0.00  2.88  72.61  0.08  9.18  1.06  0.0     7
# 210  1.51685  14.92  0.00  1.99  73.06  0.00  8.40  1.59  0.0     7
# 211  1.52065  14.36  0.00  2.02  73.42  0.00  8.44  1.64  0.0     7
# 212  1.51651  14.38  0.00  1.94  73.61  0.00  8.48  1.57  0.0     7
# 213  1.51711  14.23  0.00  2.08  73.36  0.00  8.62  1.67  0.0     7
#
# [214 rows x 10 columns]

# %%
data.duplicated().sum()
# Out:
# 1

# %%
data.drop_duplicates(keep='first', inplace = True)

# %%
data.isnull().sum()
# Out:
# RI      0
# Na      0
# Mg      0
# Al      0
# Si      0
# K       0
# Ca      0
# Ba      0
# Fe      0
# Type    0
# dtype: int64

# %%
data.dtypes
# Out:
# RI      float64
# Na      float64
# Mg      float64
# Al      float64
# Si      float64
# K       float64
# Ca      float64
# Ba      float64
# Fe      float64
# Type      int64
# dtype: object

# %%
data.boxplot()
# Out:
# <Axes: >

# %% [raw]
# No need to remove outliers as random forest does not affect with outliers.

# %%
data.nunique()
# Out:
# RI      178
# Na      142
# Mg       94
# Al      118
# Si      133
# K        65
# Ca      143
# Ba       34
# Fe       32
# Type      6
# dtype: int64

# %%
plt.title('Distribution of Refrative Index')
plt.hist(data['RI'], bins = 40);

# %% [raw]
# 'RI' column has right skewness

# %%
plt.title('Distribution of Sodium')
plt.hist(data['Na'], bins = 40);

# %% [raw]
# 'Na' column has right skewness

# %%
plt.title('Distribution of Magnesium')
plt.hist(data['Mg'], bins = 40);

# %% [raw]
# 'Mg' column has left skewness

# %%
plt.title('Distribution of Aluminum')
plt.hist(data['Al'], bins = 40);

# %% [raw]
# 'Mg' column has right skewness

# %%
plt.title('Distribution of Silicon')
plt.hist(data['Si'], bins = 40);

# %% [raw]
# 'Si' columns has left skewness

# %%
plt.title('Distribution of Potassium')
plt.hist(data['K'], bins = 40);

# %% [raw]
# 'K' column has right skewness

# %%
plt.title('Distribution of Calcium')
plt.hist(data['Ca'], bins = 40);

# %% [raw]
# 'Ca' column has right skewness

# %%
plt.title('Distribution of Barium')
plt.hist(data['Ba'], bins = 40);

# %% [raw]
# 'Ba' column has right skewness

# %%
plt.title('Distribution of Iron')
plt.hist(data['Fe'], bins = 40);

# %% [raw]
# 'Fe' column has right skewness

# %%
plt.title('Frequency of type of glass')
data['Type'].value_counts().sort_index().plot(kind= 'bar')
plt.xticks(rotation = 0);

# %% [raw]
# 'Type' column has most number of 2 values that means building windows are non float processed.

# %%
sns.heatmap(data.drop('Type', axis = 1).corr(), annot = True, cmap = 'coolwarm')
# Out:
# <Axes: >

# %% [raw]
# some of features have high or moderate correlation with each other.

# %%
data
# Out:
#           RI     Na    Mg    Al     Si     K    Ca    Ba   Fe  Type
# 0    1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.00  0.0     1
# 1    1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.00  0.0     1
# 2    1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.00  0.0     1
# 3    1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.00  0.0     1
# 4    1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.00  0.0     1
# ..       ...    ...   ...   ...    ...   ...   ...   ...  ...   ...
# 209  1.51623  14.14  0.00  2.88  72.61  0.08  9.18  1.06  0.0     7
# 210  1.51685  14.92  0.00  1.99  73.06  0.00  8.40  1.59  0.0     7
# 211  1.52065  14.36  0.00  2.02  73.42  0.00  8.44  1.64  0.0     7
# 212  1.51651  14.38  0.00  1.94  73.61  0.00  8.48  1.57  0.0     7
# 213  1.51711  14.23  0.00  2.08  73.36  0.00  8.62  1.67  0.0     7
#
# [213 rows x 10 columns]

# %% [raw]
# Random forest does not require scaling and it automatically handles inbalance.

# %% [raw]
# using smote technique to handle inbalance data.

# %%
x = data.drop('Type', axis = 1)
y = data[['Type']]

# %%
# stratify=y ensures that minority class exist both in training and testing data
x_train, x_test, y_train, y_test = train_test_split(x, y, stratify=y, test_size=0.2, random_state=42, shuffle = True)
# Defining custom sampling strategy
sampling_strategy = {
    6: 20,  # from 7 to 20 (7 are existing classes)
    5: 25,  # from 10 to 25 (10 are existing classes)
    3: 30,  # from 14 to 30 (14 are existing classes)
    7: 40   # from 23 to 40 (23 are existing classes)
}

# Initialize SMOTE with the custom strategy
smote = SMOTE(sampling_strategy = sampling_strategy, random_state=42)
x_resampled, y_resampled = smote.fit_resample(x_train, y_train)

# %%
rf = RandomForestClassifier(random_state = 42)
rf.fit(x_resampled, y_resampled)
# Out:
# RandomForestClassifier(random_state=42)

# %%
y_pred = rf.predict(x_test)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.92      0.86      0.89        14
#            2       0.92      0.73      0.81        15
#            3       0.60      1.00      0.75         3
#            5       0.75      1.00      0.86         3
#            6       0.67      1.00      0.80         2
#            7       1.00      1.00      1.00         6
#
#     accuracy                           0.86        43
#    macro avg       0.81      0.93      0.85        43
# weighted avg       0.89      0.86      0.86        43

# %% [markdown]
# ### Bagging

# %%
bagg = BaggingClassifier()

# %%
bagg.fit(x_resampled, y_resampled)
# Out:
# BaggingClassifier()

# %%
y_pred_1 = bagg.predict(x_test)
print(classification_report(y_test, y_pred_1))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.85      0.79      0.81        14
#            2       0.73      0.73      0.73        15
#            3       1.00      1.00      1.00         3
#            5       1.00      1.00      1.00         3
#            6       0.50      1.00      0.67         2
#            7       1.00      0.83      0.91         6
#
#     accuracy                           0.81        43
#    macro avg       0.85      0.89      0.85        43
# weighted avg       0.83      0.81      0.82        43

# %% [markdown]
# ### Boosting

# %%
xg = XGBClassifier(n_estimators=100)

# %%
y_resampled
# Out:
#      Type
# 0       7
# 1       1
# 2       1
# 3       1
# 4       2
# ..    ...
# 226     7
# 227     7
# 228     7
# 229     7
# 230     7
#
# [231 rows x 1 columns]

# %%
# For boosting the number should start from 0 not 1 so, mapping is important.
y_resampled_series = y_resampled['Type']
y_resampled_mod = y_resampled_series.map({1: 0, 2: 1, 3: 2, 5: 3, 6: 4, 7: 5})

# %%
y_test_series = y_test['Type']
y_test_mod = y_test_series.map({1: 0, 2: 1, 3: 2, 5: 3, 6: 4, 7: 5})

# %%
xg.fit(x_resampled, y_resampled_mod)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=100, n_jobs=None,
#               num_parallel_tree=None, objective='multi:softprob', ...)

# %%
y_pred_2 = xg.predict(x_test)
print(classification_report(y_test_mod, y_pred_2))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.71      0.77        14
#            1       0.75      0.80      0.77        15
#            2       0.67      0.67      0.67         3
#            3       1.00      1.00      1.00         3
#            4       0.67      1.00      0.80         2
#            5       0.83      0.83      0.83         6
#
#     accuracy                           0.79        43
#    macro avg       0.79      0.84      0.81        43
# weighted avg       0.80      0.79      0.79        43

# %% [raw]
# The accuracy are not very high because of small dataset.

# %% [markdown]
# ### Interview Questions

# %% [raw]
# 1) Explain Bagging and Boosting methods. How is it different from each other.
#
# Ans) Bagging : Train multiple models (usually of the same type) independently in parallel on different                random subsets of the data and then combine their outputs. Majority vote for                            classification or average for regression.
#      Boosting : Train models sequentially, where each new model focuses on the errors made by the                       previous ones. The final prediction is a weighted combination of all models.
#      Key Difference : Bagging trains multiple models in parallel on different random subsets while                           Boosting train models sequentially on error data of previous model.
#
# 2) Explain how to handle imbalance in the data.
#
# Ans) We can handle imbalance in data by using resampling techniques. There are two resampling                techniques namely oversampling and undersampling.
#      a) Oversampling : Increasing the samples of minority classes. There are two techniques:
#         i) Random Oversampling: Duplicate existing minority examples.
#         ii) SMOTE (Synthetic Minority Over-sampling Technique): Create synthetic samples based on                   nearest neighbors.
#      b) Undersampling : Reduce the samples of majority classes. There are two techniques:
#         i) Random Undersampling: Remove majority class examples at random.
#         ii) Tomek Links / Edited Nearest Neighbors: Remove borderline or noisy samples.
